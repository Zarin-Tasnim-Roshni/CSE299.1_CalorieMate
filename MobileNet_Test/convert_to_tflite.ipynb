# %%
import tensorflow as tf

model = tf.keras.models.load_model('C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Food_FineTuned_V2.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("converted_model_V2.tflite", "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Rafin\AppData\Local\Temp\tmp_u8kijne\assets
# INFO:tensorflow:Assets written to: C:\Users\Rafin\AppData\Local\Temp\tmp_u8kijne\assets
# 9610344

# %%
import os
def recreate_labels():
  labels = [folder for folder in os.listdir(r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/train') if not folder.startswith('.')]
  
  with open('labels.txt', 'w') as file:
    for label in labels:
      file.write(label)
      file.write('\n')

recreate_labels()

# %%
import os
def recreate_labels():
  labels = [folder for folder in os.listdir(r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/train') if not folder.startswith('.')]
  
  with open('labels2.txt', 'w') as file:
    for label in labels:
      file.write( '"' + str(label) + '"' )
      file.write(' , ')

recreate_labels()
