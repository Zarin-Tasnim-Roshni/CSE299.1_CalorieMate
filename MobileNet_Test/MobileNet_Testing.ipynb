# %%
from keras.applications import mobilenet_v2
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
from tensorflow.keras.applications import imagenet_utils
from IPython.display import Image

def prepare_image(file):
  img_path = 'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test_Images/'
  img = image.load_img(img_path + file, target_size=(224, 224))
  img_array = image.img_to_array(img)
  img_array_expanded_dims = np.expand_dims(img_array, axis = 0)
  return tf.keras.applications.mobilenet_v2.preprocess_input(img_array_expanded_dims)

a = input("Enter Filename: ")
b = ".jpg"

a+=b

print(tf.__version__)

print(str(a))
# Out:
# 2.10.0
# F.jpg

# %%
import tensorflow as tf

print(tf.__version__)
print("Num of GPU: ",len(tf.config.experimental.list_physical_devices("GPU")))
# Out:
# 2.10.0
# Num of GPU:  1

# %%
from IPython.display import Image

filename = 'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test_Images/'
new_directory = a 
directory, current_filename = filename.rsplit('/', 1)

new_filepath = f'{directory}/{new_directory}{current_filename}'

b = new_filepath

Image(b, width=300, height=300)

# %%
model = tf.keras.applications.mobilenet_v2.MobileNetV2()
preprocessed_image = prepare_image(a)
predictions = model.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 1s 602ms/step
# [[2.3694369e-07 8.5454470e-09 8.4356863e-08 9.7395186e-06 5.9589542e-08
#   3.9065203e-06 2.1249901e-04 1.5042188e-08 8.9661404e-04 8.7839442e-05
#   5.8120253e-07 9.4644798e-05 5.7466941e-08 4.6562376e-03 2.5750279e-07
#   2.1314097e-06 3.8537792e-08 6.1414044e-05 1.1591329e-07 1.2291434e-05
#   2.2697566e-06 1.6260381e-09 1.0389007e-06 1.3098650e-08 2.9853985e-07
#   1.6283325e-06 7.9683359e-06 4.0210418e-07 9.9366319e-01 7.1398984e-11
#   1.8534983e-08 5.4511966e-06 3.9774292e-07 1.2039052e-10 1.1406180e-09
#   1.5098600e-06 1.2067157e-08 1.7762637e-05 3.0002834e-09 1.0114514e-09
#   2.9069605e-08 1.4503365e-08 1.9618610e-05 1.9201610e-07 1.4400439e-06
#   4.0842551e-05 1.9770114e-06 1.9032898e-07 1.7436268e-08 2.4274233e-10
#   2.1181107e-08 7.8157718e-06 2.4783767e-05 3.0157469e-06 1.5801001e-04
#   9.0421258e-07 8.2126576e-08 3.7160478e-07]]

# %% [markdown]
# # New Section
