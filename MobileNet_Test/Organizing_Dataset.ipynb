# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from  tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
from keras.applications import MobileNetV2
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1

# %%
source_directory = r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food'
os.chdir(r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food')
if os.path.isdir('train/0/') is False:
     os.mkdir("train")
     for subdirectory_name in os.listdir(source_directory):
          subdirectory_path = os.path.join(source_directory, subdirectory_name)
          shutil.move(f'{subdirectory_name}','train') 
     os.mkdir("valid")
     os.mkdir("test")

# %%
source_directory = r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/train'
for subdirectory_name in os.listdir(source_directory):
     subdirectory_path = os.path.join(source_directory, subdirectory_name)
     os.mkdir(f'valid/{subdirectory_name}')
     os.mkdir(f'test/{subdirectory_name}')

# %%
source_directory = r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/train'
for subdirectory_name in os.listdir(source_directory):
     subdirectory_path = os.path.join(source_directory, subdirectory_name)
     
     valid_samples = random.sample(os.listdir(f'train/{subdirectory_name}'),30)
     for file_name in valid_samples:
                     source_file_path = os.path.join(subdirectory_path, file_name)
                     shutil.move(f'train/{subdirectory_name}/{file_name}',f'valid/{subdirectory_name}')

# %%
source_directory = r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/train'
for subdirectory_name in os.listdir(source_directory):
     subdirectory_path = os.path.join(source_directory, subdirectory_name)
     files_in_subdirectory = os.listdir(subdirectory_path)
     
     test_samples = random.sample(os.listdir(f'train/{subdirectory_name}'),min(5,len(files_in_subdirectory)))
     for file_name2 in test_samples:
                     source_file_path = os.path.join(subdirectory_path, file_name2)
                     shutil.move(f'train/{subdirectory_name}/{file_name2}',f'test/{subdirectory_name}')

# %%
train_path = r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/train'
valid_path = r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/valid'
test_path  = r'C:/Users/Rafin/OneDrive/Desktop/NSU/NSU 10th Semester/CSE299/PROJECT/CSE299.1_CalorieMate/MobileNet_Test/Bangla_Food/test'

# %%
train_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(directory=train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(directory=valid_path, target_size=(224,224), batch_size=10)
test_batches  = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(directory=test_path, target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 5701 images belonging to 58 classes.
# Found 1740 images belonging to 58 classes.
# Found 290 images belonging to 58 classes.
